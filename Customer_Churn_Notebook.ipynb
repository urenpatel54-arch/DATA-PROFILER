# %% [markdown]
# # Customer Churn Analysis Project

# %% [markdown]
# ## Objective
# Analyze customer data, perform data cleaning, exploratory data analysis (EDA), and prepare a cleaned dataset for future churn prediction.

# %% [markdown]
# ## Data Collection
# Data is collected from CSV, JSON, SQL Database and API sources.

# %%
import pandas as pd
import numpy as np
import sqlite3
import requests
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Main Analysis

# %%
# Place your existing project code here
print("Customer Churn Analysis Project")

# %% [markdown]
# ## Conclusion
#
# 1. Data collected from CSV, JSON, SQL and API.
# 2. Missing values were identified and handled.
# 3. Duplicate records were removed.
# 4. Exploratory Data Analysis was performed.
# 5. Correlation analysis was completed.
# 6. Cleaned dataset was generated successfully.
# 7. The dataset is ready for future machine learning applications.
